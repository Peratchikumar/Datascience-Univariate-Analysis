# %%
#Interquartile Range (IQR)

# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
#Quan=["ssc_p"," hsc_p", "etest_p", "degree_p"," mba_p"," salary"] - Quan - Numerical Data - int64,float64
#Qual=["gender", "ssc_b", "hsc_b", "degree_t", "workex", "specialisation", "status"] - Qual - Categorical Data - object,char-character

# %%
dataset.columns #Column Names
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
dir(dataset) #Dataset supported functions
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...

# %%
dataset.dtypes #Overall datatypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
dataset["gender"].dtypes #Column wise dataype result
# Out:
# dtype('O')

# %%
for columnName in dataset.columns: #Print the column name in the dataset - For Loop
    print(columnName)
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
if (dataset["ssc_p"].dtype=='0'):
    print("Qualitative")
else:
    print("Quantitative")
# Out:
# Quantitative

# %%
Qualitative=[]
Quantitative=[]

for columnName in dataset.columns: #Print the column name in the dataset - For Loop
    print(columnName)
    if(dataset[columnName].dtype=='object'):
        print("Qualitative")
        Qualitative.append(columnName)
    else:
        print("Quantitative")
        Quantitative.append(columnName)
# Out:
# sl_no
# Quantitative
# gender
# Qualitative
# ssc_p
# Quantitative
# ssc_b
# Qualitative
# hsc_p
# Quantitative
# hsc_b
# Qualitative
# hsc_s
# Qualitative
# degree_p
# Quantitative
# degree_t
# Qualitative
# workex
# Qualitative
# etest_p
# Quantitative
# specialisation
# Qualitative
# mba_p
# Quantitative
# status
# Qualitative
# salary
# Quantitative

# %%
Qualitative
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
Quantitative
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
def QualitativeQuantitative(dataset): #Function - is a procedure
    Qualitative=[]
    Quantitative=[]
    
    for columnName in dataset.columns: #Print the column name in the dataset - For Loop
        print(columnName)
        if(dataset[columnName].dtype=='object'):
            print("Qualitative")
            Qualitative.append(columnName)
        else:
            print("Quantitative")
            Quantitative.append(columnName)
    return Qualitative, Quantitative

# %%
QualitativeQuantitative(dataset) #Function Call
# Out:
# sl_no
# Quantitative
# gender
# Qualitative
# ssc_p
# Quantitative
# ssc_b
# Qualitative
# hsc_p
# Quantitative
# hsc_b
# Qualitative
# hsc_s
# Qualitative
# degree_p
# Quantitative
# degree_t
# Qualitative
# workex
# Qualitative
# etest_p
# Quantitative
# specialisation
# Qualitative
# mba_p
# Quantitative
# status
# Qualitative
# salary
# Quantitative
# (['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'],
#  ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'])

# %%
Qualitative,Quantitative= QualitativeQuantitative(dataset)
# Out:
# sl_no
# Quantitative
# gender
# Qualitative
# ssc_p
# Quantitative
# ssc_b
# Qualitative
# hsc_p
# Quantitative
# hsc_b
# Qualitative
# hsc_s
# Qualitative
# degree_p
# Quantitative
# degree_t
# Qualitative
# workex
# Qualitative
# etest_p
# Quantitative
# specialisation
# Qualitative
# mba_p
# Quantitative
# status
# Qualitative
# salary
# Quantitative

# %%
Qualitative
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
Quantitative
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# #Measure of central tendency

# %%
dataset["ssc_p"].mean() #To identify the mean
# Out:
# np.float64(67.30339534883721)

# %%
dataset["ssc_p"].median() #To identify the median
# Out:
# 67.0

# %%
dataset["ssc_p"].mode() #To identify the mode, without [0]
# Out:
# 0    62.0
# Name: ssc_p, dtype: float64

# %%
dataset["ssc_p"].mode()[0] #To identify the mode, with [0]
# Out:
# np.float64(62.0)

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive=pd.DataFrame() #For table creation

# %%
descriptive=pd.DataFrame(index=["Mean", "Median", "Mode"],columns=Quantitative) #Index

# %%
descriptive #Fuction Call
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive["hsc_p"]["Median"] #1.Column-hsc_p, 2.Index-Median-Row, Without [0]
# Out:
# nan

# %%
descriptive["hsc_p"]["Median"]=0 #1.Column-hsc_p, 2.Index-Median-Row, With [0]
# Out:
# C:\Users\bkann\AppData\Local\Temp\ipykernel_11208\285897510.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive["hsc_p"]["Median"]=0 #1.Column-hsc_p, 2.Index-Median-Row, With [0]

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN     0      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive=pd.DataFrame(index=["Mean", "Median", "Mode"],columns=Quantitative) #Index
for ColumnName in Quantitative:
    descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
# Out:
# C:\Users\bkann\AppData\Local\Temp\ipykernel_11208\3855684250.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    NaN        NaN        NaN        NaN        NaN        NaN
# Mode      NaN        NaN        NaN        NaN        NaN        NaN
#
#                salary
# Mean    288655.405405
# Median            NaN
# Mode              NaN

# %%
descriptive=pd.DataFrame(index=["Mean", "Median", "Mode"],columns=Quantitative) #Index
for ColumnName in Quantitative:
    descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
    descriptive[ColumnName]["Median"]=dataset[ColumnName].median()
    descriptive[ColumnName]["Mode"]=dataset[ColumnName].mode()[0]
# Out:
# C:\Users\bkann\AppData\Local\Temp\ipykernel_11208\3131477293.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
# ...

# %%
descriptive #Function Call
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %%
import numpy as np #Numpy - for numerical calculation

# %%
np.percentile(dataset["ssc_p"],100)
# Out:
# np.float64(89.4)

# %%
descriptive=pd.DataFrame(index=["Mean", "Median", "Mode", "Q1:25%", "Q2:50%", "Q3:75%", "99%", "Q4:100%", "IQR", "1.5rule", "Lesser", "Greater", "Min", "Max"],columns=Quantitative) #Index
for ColumnName in Quantitative:
    descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
    descriptive[ColumnName]["Median"]=dataset[ColumnName].median()
    descriptive[ColumnName]["Mode"]=dataset[ColumnName].mode()[0]
    descriptive[ColumnName]["Q1:25%"]=dataset.describe()[ColumnName]["25%"]
    descriptive[ColumnName]["Q2:50%"]=dataset.describe()[ColumnName]["50%"]
    descriptive[ColumnName]["Q3:75%"]=dataset.describe()[ColumnName]["75%"]
    descriptive[ColumnName]["99%"]=np.percentile(dataset[ColumnName],99)
    descriptive[ColumnName]["Q4:100%"]=dataset.describe()[ColumnName]["max"]
    descriptive[ColumnName]["IQR"]=descriptive[ColumnName]["Q3:75%"]-descriptive[ColumnName]["Q1:25%"]
    descriptive[ColumnName]["1.5rule"]=1.5*descriptive[ColumnName]["IQR"]
    descriptive[ColumnName]["Lesser"]=descriptive[ColumnName]["Q1:25%"]-descriptive[ColumnName]["1.5rule"]
    descriptive[ColumnName]["Greater"]=descriptive[ColumnName]["Q3:75%"]+descriptive[ColumnName]["1.5rule"]
    descriptive[ColumnName]["Min"]=dataset[ColumnName].min()
    descriptive[ColumnName]["Max"]=dataset[ColumnName].max()
# Out:
# C:\Users\bkann\AppData\Local\Temp\ipykernel_11208\3661060166.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
# ...

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100%   215.0       89.4       97.7       91.0       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %%
#Finding - Outliers Column

# %%
descriptive["hsc_p"]["Min"]<descriptive["hsc_p"]["Lesser"]
# Out:
# np.True_

# %%
Lesser=[]
Greater=[]

for ColumnName in Quantitative: #For Loop
    if(descriptive[ColumnName]["Min"]<descriptive[ColumnName]["Lesser"]):
       Lesser.append(ColumnName)
    if(descriptive[ColumnName]["Max"]>descriptive[ColumnName]["Greater"]):
        Greater.append(ColumnName)

# %%
Lesser
# Out:
# ['hsc_p']

# %%
Greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
#Replacing Outliers

# %%
for ColumnName in Lesser:
    dataset[ColumnName][dataset[ColumnName]<descriptive[ColumnName]["Lesser"]]=descriptive[ColumnName]["Lesser"]
for ColumnName in Greater:
    dataset[ColumnName][dataset[ColumnName]>descriptive[ColumnName]["Greater"]]=descriptive[ColumnName]["Greater"]
# Out:
# C:\Users\bkann\AppData\Local\Temp\ipykernel_11208\4002164317.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataset[ColumnName][dataset[ColumnName]<descriptive[ColumnName]["Lesser"]]=descriptive[ColumnName]["Lesser"]
# ...

# %%
descriptive=pd.DataFrame(index=["Mean", "Median", "Mode", "Q1:25%", "Q2:50%", "Q3:75%", "99%", "Q4:100%", "IQR", "1.5rule", "Lesser", "Greater", "Min", "Max"],columns=Quantitative) #Index
for ColumnName in Quantitative:
    descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
    descriptive[ColumnName]["Median"]=dataset[ColumnName].median()
    descriptive[ColumnName]["Mode"]=dataset[ColumnName].mode()[0]
    descriptive[ColumnName]["Q1:25%"]=dataset.describe()[ColumnName]["25%"]
    descriptive[ColumnName]["Q2:50%"]=dataset.describe()[ColumnName]["50%"]
    descriptive[ColumnName]["Q3:75%"]=dataset.describe()[ColumnName]["75%"]
    descriptive[ColumnName]["99%"]=np.percentile(dataset[ColumnName],99)
    descriptive[ColumnName]["Q4:100%"]=dataset.describe()[ColumnName]["max"]
    descriptive[ColumnName]["IQR"]=descriptive[ColumnName]["Q3:75%"]-descriptive[ColumnName]["Q1:25%"]
    descriptive[ColumnName]["1.5rule"]=1.5*descriptive[ColumnName]["IQR"]
    descriptive[ColumnName]["Lesser"]=descriptive[ColumnName]["Q1:25%"]-descriptive[ColumnName]["1.5rule"]
    descriptive[ColumnName]["Greater"]=descriptive[ColumnName]["Q3:75%"]+descriptive[ColumnName]["1.5rule"]
    descriptive[ColumnName]["Min"]=dataset[ColumnName].min()
    descriptive[ColumnName]["Max"]=dataset[ColumnName].max()
# Out:
# C:\Users\bkann\AppData\Local\Temp\ipykernel_11208\1058876773.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
# ...

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0     91.129      83.86       97.0    76.1142
# Q4:100%   215.0       89.4      91.15       88.5       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %%
Lesser=[]
Greater=[]

for ColumnName in Quantitative: #For Loop
    if(descriptive[ColumnName]["Min"]<descriptive[ColumnName]["Lesser"]):
       Lesser.append(ColumnName)
    if(descriptive[ColumnName]["Max"]>descriptive[ColumnName]["Greater"]):
        Greater.append(ColumnName)

# %%
Lesser
# Out:
# []

# %%
Greater
# Out:
# []

# %%
#Frequency

# %%
dataset["ssc_p"].value_counts() #Value Count
# Out:
# ssc_p
# 62.00    11
# 63.00    10
# 67.00     9
# 52.00     9
# 73.00     9
#          ..
# 69.70     1
# 80.92     1
# 83.00     1
# 86.50     1
# 80.60     1
# Name: count, Length: 103, dtype: int64

# %%
freqTable=pd.DataFrame(columns=["Unique_Values","Frequency","Relative Frequency", "cumsum"])

# %%
freqTable
# Out:
# Empty DataFrame
# Columns: [Unique_Values, Frequency, Relative Frequency, cumsum]
# Index: []

# %%
freqTable["Unique_Values"]=dataset["ssc_p"].value_counts().index #Index

# %%
freqTable
# Out:
#      Unique_Values Frequency Relative Frequency cumsum
# 0            62.00       NaN                NaN    NaN
# 1            63.00       NaN                NaN    NaN
# 2            67.00       NaN                NaN    NaN
# 3            52.00       NaN                NaN    NaN
# 4            73.00       NaN                NaN    NaN
# ..             ...       ...                ...    ...
# 98           69.70       NaN                NaN    NaN
# 99           80.92       NaN                NaN    NaN
# 100          83.00       NaN                NaN    NaN
# 101          86.50       NaN                NaN    NaN
# 102          80.60       NaN                NaN    NaN
#
# [103 rows x 4 columns]

# %%
freqTable["Unique_Values"]=dataset["ssc_p"].value_counts().index 
freqTable["Frequency"]=dataset["ssc_p"].value_counts().values
freqTable["Relative Frequency"]=(freqTable["Frequency"]/103)
freqTable["cumsum"]=freqTable["Relative Frequency"].cumsum()

# %%
def freqTable(ColumnName,dataset):
    freqTable=pd.DataFrame(columns=["Unique_Values","Frequency","Relative Frequency", "cumsum"])
    freqTable["Unique_Values"]=dataset[ColumnName].value_counts().index 
    freqTable["Frequency"]=dataset[ColumnName].value_counts().values
    freqTable["Relative Frequency"]=(freqTable["Frequency"]/103)
    freqTable["cumsum"]=freqTable["Relative Frequency"].cumsum()
    return freqTable

# %%
freqTable("hsc_p",dataset)
# Out:
#     Unique_Values  Frequency  Relative Frequency    cumsum
# 0           63.00         14            0.135922  0.135922
# 1           62.00         12            0.116505  0.252427
# 2           60.00          9            0.087379  0.339806
# 3           67.00          9            0.087379  0.427184
# 4           70.00          8            0.077670  0.504854
# ..            ...        ...                 ...       ...
# 86          70.29          1            0.009709  2.048544
# 87          83.83          1            0.009709  2.058252
# 88          70.40          1            0.009709  2.067961
# 89          90.90          1            0.009709  2.077670
# 90          61.33          1            0.009709  2.087379
#
# [91 rows x 4 columns]

# %%
def Univariate(dataset,Quantitative):
    descriptive=pd.DataFrame(index=["Mean", "Median", "Mode", "Q1:25%", "Q2:50%", "Q3:75%", "99%", "Q4:100%", "IQR", "1.5rule", "Lesser", "Greater", "Min", "Max"],columns=Quantitative) #Index
    for ColumnName in Quantitative:
        descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
        descriptive[ColumnName]["Median"]=dataset[ColumnName].median()
        descriptive[ColumnName]["Mode"]=dataset[ColumnName].mode()[0]
        descriptive[ColumnName]["Q1:25%"]=dataset.describe()[ColumnName]["25%"]
        descriptive[ColumnName]["Q2:50%"]=dataset.describe()[ColumnName]["50%"]
        descriptive[ColumnName]["Q3:75%"]=dataset.describe()[ColumnName]["75%"]
        descriptive[ColumnName]["99%"]=np.percentile(dataset[ColumnName],99)
        descriptive[ColumnName]["Q4:100%"]=dataset.describe()[ColumnName]["max"]
        descriptive[ColumnName]["IQR"]=descriptive[ColumnName]["Q3:75%"]-descriptive[ColumnName]["Q1:25%"]
        descriptive[ColumnName]["1.5rule"]=1.5*descriptive[ColumnName]["IQR"]
        descriptive[ColumnName]["Lesser"]=descriptive[ColumnName]["Q1:25%"]-descriptive[ColumnName]["1.5rule"]
        descriptive[ColumnName]["Greater"]=descriptive[ColumnName]["Q3:75%"]+descriptive[ColumnName]["1.5rule"]
        descriptive[ColumnName]["Min"]=dataset[ColumnName].min()
        descriptive[ColumnName]["Max"]=dataset[ColumnName].max()
    return descriptive

# %%
Univariate(dataset,Quantitative)
# Out:
# C:\Users\bkann\AppData\Local\Temp\ipykernel_11208\2965842765.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
# ...

# %%
#HSK - Histogram, Skewness, Kurtosis

# %%
dir(dataset["ssc_p"]) #To show supporting functions
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
dataset["ssc_p"].skew()
# Out:
# np.float64(-0.13264949031456927)

# %%
dataset["ssc_p"].kurtosis()
# Out:
# np.float64(-0.6075102066986688)

# %%
def Univariate(dataset,Quantitative):
    descriptive=pd.DataFrame(index=["Mean", "Median", "Mode", "Q1:25%", "Q2:50%", "Q3:75%", "99%", "Q4:100%", "IQR", "1.5rule", "Lesser", "Greater", "Min", "Max", "kurtosis", "skew"],columns=Quantitative) #Index
    for ColumnName in Quantitative:
        descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
        descriptive[ColumnName]["Median"]=dataset[ColumnName].median()
        descriptive[ColumnName]["Mode"]=dataset[ColumnName].mode()[0]
        descriptive[ColumnName]["Q1:25%"]=dataset.describe()[ColumnName]["25%"]
        descriptive[ColumnName]["Q2:50%"]=dataset.describe()[ColumnName]["50%"]
        descriptive[ColumnName]["Q3:75%"]=dataset.describe()[ColumnName]["75%"]
        descriptive[ColumnName]["99%"]=np.percentile(dataset[ColumnName],99)
        descriptive[ColumnName]["Q4:100%"]=dataset.describe()[ColumnName]["max"]
        descriptive[ColumnName]["IQR"]=descriptive[ColumnName]["Q3:75%"]-descriptive[ColumnName]["Q1:25%"]
        descriptive[ColumnName]["1.5rule"]=1.5*descriptive[ColumnName]["IQR"]
        descriptive[ColumnName]["Lesser"]=descriptive[ColumnName]["Q1:25%"]-descriptive[ColumnName]["1.5rule"]
        descriptive[ColumnName]["Greater"]=descriptive[ColumnName]["Q3:75%"]+descriptive[ColumnName]["1.5rule"]
        descriptive[ColumnName]["Min"]=dataset[ColumnName].min()
        descriptive[ColumnName]["Max"]=dataset[ColumnName].max()
        descriptive[ColumnName]["kurtosis"]=dataset[ColumnName].kurtosis()
        descriptive[ColumnName]["skew"]=dataset[ColumnName].skew()
    
    return descriptive

# %%
Univariate(dataset,Quantitative)
# Out:
# C:\Users\bkann\AppData\Local\Temp\ipykernel_11208\1334888774.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
# ...

# %%
#Standard deviation and Variance

# %%
dataset["ssc_p"].var() #Variance
# Out:
# 117.22837673549229

# %%
dataset["ssc_p"].std() #Standard Deviation
# Out:
# 10.827205398231452

# %%
def Univariate(dataset,Quantitative):
    descriptive=pd.DataFrame(index=["Mean", "Median", "Mode", "Q1:25%", "Q2:50%", "Q3:75%", "99%", "Q4:100%", "IQR", "1.5rule", "Lesser", "Greater", "Min", "Max", "kurtosis", "skew", "var", "std"],columns=Quantitative) #Index
    for ColumnName in Quantitative:
        descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
        descriptive[ColumnName]["Median"]=dataset[ColumnName].median()
        descriptive[ColumnName]["Mode"]=dataset[ColumnName].mode()[0]
        descriptive[ColumnName]["Q1:25%"]=dataset.describe()[ColumnName]["25%"]
        descriptive[ColumnName]["Q2:50%"]=dataset.describe()[ColumnName]["50%"]
        descriptive[ColumnName]["Q3:75%"]=dataset.describe()[ColumnName]["75%"]
        descriptive[ColumnName]["99%"]=np.percentile(dataset[ColumnName],99)
        descriptive[ColumnName]["Q4:100%"]=dataset.describe()[ColumnName]["max"]
        descriptive[ColumnName]["IQR"]=descriptive[ColumnName]["Q3:75%"]-descriptive[ColumnName]["Q1:25%"]
        descriptive[ColumnName]["1.5rule"]=1.5*descriptive[ColumnName]["IQR"]
        descriptive[ColumnName]["Lesser"]=descriptive[ColumnName]["Q1:25%"]-descriptive[ColumnName]["1.5rule"]
        descriptive[ColumnName]["Greater"]=descriptive[ColumnName]["Q3:75%"]+descriptive[ColumnName]["1.5rule"]
        descriptive[ColumnName]["Min"]=dataset[ColumnName].min()
        descriptive[ColumnName]["Max"]=dataset[ColumnName].max()
        descriptive[ColumnName]["kurtosis"]=dataset[ColumnName].kurtosis()
        descriptive[ColumnName]["skew"]=dataset[ColumnName].skew()
        descriptive[ColumnName]["var"]=dataset[ColumnName].var()
        descriptive[ColumnName]["std"]=dataset[ColumnName].std()
        
    return descriptive

# %%
Univariate(dataset,Quantitative)
# Out:
# C:\Users\bkann\AppData\Local\Temp\ipykernel_11208\2773266403.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
# ...
